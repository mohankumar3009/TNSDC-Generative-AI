# %% [markdown]
# Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Define generator model

# %%
def generator_model(latent_dim):
  model = tf.keras.Sequential() #Object Creation
  model.add(layers.Dense(128,input_dim = latent_dim, activation = "relu"))
  model.add(layers.Dense(784, activation = "sigmoid"))
  model.add(layers.Reshape((28, 28, 1)))
  return model

# %% [markdown]
# Define Discriminator model

# %%
def discriminator_model(img_shape):
  model = tf.keras.Sequential() #Object Creation
  model.add(layers.Flatten(input_shape = img_shape))
  model.add(layers.Dense(128, activation = "relu"))
  model.add(layers.Dense(1, activation = "sigmoid"))
  return model

# %% [markdown]
# Denine the GAN model for Combining Generator and Discriminator Model

# %%
def build_gan(generator, discriminator):
  discriminator.trainable = False #Set the discriminator not to the trainable GAN training

  model = tf.keras.Sequential()
  model.add(generator)
  model.add(discriminator)
  return model

# %% [markdown]
# Load MNIST Dataset

# %%
(x_train,_), (_, _) =  tf.keras.datasets.mnist.load_data()
x_train=x_train/ 255.0 #normalization pixel values between 0 to 1
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# Reshape images

# %%
x_train = x_train.reshape((x_train.shape[0], 28, 28,1))

# %% [markdown]
# Build and Compile the discriminator

# %%
discriminator = discriminator_model((28, 28, 1))
discriminator.compile(optimizer="adam" , loss="binary_crossentropy" , metrics=['accuracy'])

# %% [markdown]
# Build and Compile the generator

# %%
latent_dim = 100
generator = generator_model(latent_dim)

# %% [markdown]
# Build and compile the GAN

# %%
discriminator.trainable = False

gan = build_gan (generator, discriminator)
gan.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# Training the GAN

# %%
epochs = 10000
batch_size = 64

for epoch in range(epochs):
    # Generate random noise as input to the generator
    noise = np.random.normal(0, 1, size=(batch_size, latent_dim))

    # Train the generator by fooling the discriminator
    labels_gan = np.ones((batch_size, 1))
    g_loss = gan.train_on_batch(noise, labels_gan)

    # Print the output
    if epoch % 100 == 0:
        print(f"Epoch: {epoch}, Generator Loss: {g_loss}")
# Out:
# Epoch: 0, Generator Loss: 1.2145326137542725
# Epoch: 100, Generator Loss: 0.0036130044609308243
# Epoch: 200, Generator Loss: 0.001706314622424543
# Epoch: 300, Generator Loss: 0.0011048890883103013
# Epoch: 400, Generator Loss: 0.0007149839075282216
# Epoch: 500, Generator Loss: 0.0005862733814865351
# Epoch: 600, Generator Loss: 0.0004403307393658906
# Epoch: 700, Generator Loss: 0.0003343889256939292
# Epoch: 800, Generator Loss: 0.0003120279870927334
# Epoch: 900, Generator Loss: 0.00022637132497038692
# Epoch: 1000, Generator Loss: 0.00021888717310503125
# Epoch: 1100, Generator Loss: 0.0001781945175025612
# Epoch: 1200, Generator Loss: 0.00017536984523758292
# Epoch: 1300, Generator Loss: 0.00015154885477386415
# Epoch: 1400, Generator Loss: 0.0001451164425816387
# Epoch: 1500, Generator Loss: 0.00012555861030705273
# Epoch: 1600, Generator Loss: 0.0001222121500177309
# Epoch: 1700, Generator Loss: 0.00011643765901681036
# Epoch: 1800, Generator Loss: 9.454009705223143e-05
# Epoch: 1900, Generator Loss: 9.451487858314067e-05
# Epoch: 2000, Generator Loss: 8.493233326589689e-05
# Epoch: 2100, Generator Loss: 7.927720434963703e-05
# Epoch: 2200, Generator Loss: 7.295996329048648e-05
# Epoch: 2300, Generator Loss: 7.252632349263877e-05
# Epoch: 2400, Generator Loss: 6.541064794873819e-05
# Epoch: 2500, Generator Loss: 5.977966793579981e-05
# Epoch: 2600, Generator Loss: 5.38523199793417e-05
# Epoch: 2700, Generator Loss: 5.8776186051545665e-05
# Epoch: 2800, Generator Loss: 4.818793968297541e-05
# Epoch: 2900, Generator Loss: 4.835008076042868e-05
# Epoch: 3000, Generator Loss: 4.65673983853776e-05
# Epoch: 3100, Generator Loss: 4.603443812811747e-05
# Epoch: 3200, Generator Loss: 4.55851259175688e-05
# Epoch: 3300, Generator Loss: 3.9470331103075296e-05
# Epoch: 3400, Generator Loss: 4.0057118894765154e-05
# Epoch: 3500, Generator Loss: 3.5968547308584675e-05
# Epoch: 3600, Generator Loss: 3.751867188839242e-05
# Epoch: 3700, Generator Loss: 3.5216995456721634e-05
# Epoch: 3800, Generator Loss: 3.3941199944820255e-05
# Epoch: 3900, Generator Loss: 2.9912289392086677e-05
# Epoch: 4000, Generator Loss: 3.086440119659528e-05
# Epoch: 4100, Generator Loss: 3.0323069950100034e-05
# Epoch: 4200, Generator Loss: 2.8252194169908762e-05
# Epoch: 4300, Generator Loss: 2.688822860363871e-05
# Epoch: 4400, Generator Loss: 2.4804470740491524e-05
# Epoch: 4500, Generator Loss: 2.4288958229590207e-05
# Epoch: 4600, Generator Loss: 2.4864784791134298e-05
# Epoch: 4700, Generator Loss: 2.3425087420037016e-05
# Epoch: 4800, Generator Loss: 2.314623816346284e-05
# Epoch: 4900, Generator Loss: 2.1107382053742185e-05
# Epoch: 5000, Generator Loss: 2.132180998160038e-05
# Epoch: 5100, Generator Loss: 2.0844705431954935e-05
# Epoch: 5200, Generator Loss: 1.9338884158059955e-05
# Epoch: 5300, Generator Loss: 1.9074865122092888e-05
# Epoch: 5400, Generator Loss: 1.867472383310087e-05
# Epoch: 5500, Generator Loss: 1.7405029211658984e-05
# Epoch: 5600, Generator Loss: 1.752834032231476e-05
# Epoch: 5700, Generator Loss: 1.7281075997743756e-05
# Epoch: 5800, Generator Loss: 1.5817400708328933e-05
# Epoch: 5900, Generator Loss: 1.612289997865446e-05
# Epoch: 6000, Generator Loss: 1.5023453670437448e-05
# Epoch: 6100, Generator Loss: 1.4636586456617806e-05
# Epoch: 6200, Generator Loss: 1.3870937436877284e-05
# Epoch: 6300, Generator Loss: 1.4066530638956465e-05
# Epoch: 6400, Generator Loss: 1.4078330423217267e-05
# Epoch: 6500, Generator Loss: 1.3852943084202707e-05
# Epoch: 6600, Generator Loss: 1.3191316611482762e-05
# Epoch: 6700, Generator Loss: 1.2593223800649866e-05
# Epoch: 6800, Generator Loss: 1.2339794920990244e-05
# Epoch: 6900, Generator Loss: 1.2009767488052603e-05
# Epoch: 7000, Generator Loss: 1.1648901818261947e-05
# Epoch: 7100, Generator Loss: 1.2217817129567266e-05
# Epoch: 7200, Generator Loss: 1.1059688404202461e-05
# Epoch: 7300, Generator Loss: 1.092020102078095e-05
# Epoch: 7400, Generator Loss: 1.0906094757956453e-05
# Epoch: 7500, Generator Loss: 1.0686286259442568e-05
# Epoch: 7600, Generator Loss: 1.025268738885643e-05
# Epoch: 7700, Generator Loss: 9.679843969934154e-06
# Epoch: 7800, Generator Loss: 9.797251550480723e-06
# Epoch: 7900, Generator Loss: 9.656618203734979e-06
# Epoch: 8000, Generator Loss: 9.505193702352699e-06
# Epoch: 8100, Generator Loss: 9.257512829208281e-06
# Epoch: 8200, Generator Loss: 8.609991709818132e-06
# Epoch: 8300, Generator Loss: 8.85068584466353e-06
# Epoch: 8400, Generator Loss: 8.538923793821596e-06
# Epoch: 8500, Generator Loss: 8.584836905356497e-06
# Epoch: 8600, Generator Loss: 8.128874469548464e-06
# Epoch: 8700, Generator Loss: 8.230939783970825e-06
# Epoch: 8800, Generator Loss: 8.226767022279091e-06
# Epoch: 8900, Generator Loss: 7.94163588579977e-06
# Epoch: 9000, Generator Loss: 7.582247690152144e-06
# Epoch: 9100, Generator Loss: 7.602043751830934e-06
# Epoch: 9200, Generator Loss: 7.708351404289715e-06
# Epoch: 9300, Generator Loss: 7.469077445421135e-06
# Epoch: 9400, Generator Loss: 7.326605100388406e-06
# Epoch: 9500, Generator Loss: 6.942394520592643e-06
# Epoch: 9600, Generator Loss: 6.958659469091799e-06
# Epoch: 9700, Generator Loss: 6.993645001784898e-06
# Epoch: 9800, Generator Loss: 6.7024575400864705e-06
# Epoch: 9900, Generator Loss: 6.683954779873602e-06
